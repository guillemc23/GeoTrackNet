# %%
from migration.models import vrnn
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
generative_distribution_class = vrnn.ConditionalBernoulliDistribution

# %%
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_2403/1367071083.py:3: The name tf.log is deprecated. Please use tf.math.log instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2403/1367071083.py in <module>
#       1 import tensorflow as tf
#       2
# ----> 3 generative_bias_init = -tf.log(1. / tf.clip_by_value(mean, 0.0001, 0.9999) - 1)
#
# NameError: name 'mean' is not defined

# %%
model = vrnn.create_vrnn(inputs.get_shape().as_list()[2],
                             config.latent_size,
                             generative_distribution_class,
                             generative_bias_init=generative_bias_init,
                             raw_sigma_bias=0.5)
