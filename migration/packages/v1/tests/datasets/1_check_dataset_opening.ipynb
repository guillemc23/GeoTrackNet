# %%
from migration.datasets import create_AIS_dataset

# %%
print(4)
# Out:
# 4

# %% [markdown]
# mean file generated with the following bins

# %%
inputs, targets, mmsis, time_starts, time_ends, lengths, mean =  create_AIS_dataset('../../data/ct_2017010203_10_20/ct_2017010203_10_20_train.pkl', 
                   '../../data/ct_2017010203_10_20/mean.pkl',
                   32,
                   99999, # not used lol
                   300,
                   300, 
                   30,
                   72, 
                   shuffle=False,
                   repeat=False)
# Out:
# WARNING:tensorflow:From /workspaces/GeoTrackNet/migration/packages/v1/src/migration/datasets.py:88: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /workspaces/GeoTrackNet/migration/packages/v1/src/migration/datasets.py:111: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
# ...

# %% [markdown]
# evaluate

# %%
import tensorflow as tf
with tf.Session() as sess:
    inputs, targets, mmsis, time_starts, time_ends, lengths, mean = sess.run([inputs, targets, mmsis, time_starts, time_ends, lengths, mean])
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_7164/1718419132.py:2: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# 2025-06-20 09:51:28.640203: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2025-06-20 09:51:28.655877: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2688010000 Hz
# 2025-06-20 09:51:28.658034: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2dca8320 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-06-20 09:51:28.658091: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
# (time index, batch_size, number of features)
inputs.shape
# Out:
# (99, 32, 702)

# %%
# (time index, batch_size, number of features)
targets.shape
# Out:
# (99, 32, 702)

# %% [markdown]
# targets is just inputs but one step further in time

# %%
inputs[1:, :, :].shape
# Out:
# (98, 32, 702)

# %%
assert (inputs[1:, :, :]+ mean.reshape((1,1,702)) == targets[:-1, :, :]).all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_7164/4112455866.py in <module>
# ----> 1 assert (inputs[1:, :, :]+ mean.reshape((1,1,702)) == targets[:-1, :, :]).all()
#
# AssertionError:
