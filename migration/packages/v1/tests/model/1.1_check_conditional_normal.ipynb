# %%
import sonnet as snt
import tensorflow as tf
tf.compat.v1.enable_eager_execution()
import numpy as np

# %%
latent_size = 64
_DEFAULT_INITIALIZERS = {"w": tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform",seed=111),
                         "b": tf.compat.v1.zeros_initializer()}

# %%
from migration.models.vrnn import ConditionalNormalDistribution


prior = ConditionalNormalDistribution(size=latent_size, hidden_layer_sizes=[latent_size], sigma_min=0, raw_sigma_bias=0.25, initializers=_DEFAULT_INITIALIZERS)

# %%
rnn_out = tf.random.uniform((32,64), dtype=tf.float32)

# %%
latent_dist_prior = prior(rnn_out)

# %%
latent_dist_prior.cdf(0.6)
# Out:
# <tf.Tensor: id=233, shape=(32, 64), dtype=float32, numpy=
# array([[0.8126615 , 0.72531533, 0.8973433 , ..., 0.70371747, 0.63006896,
#         0.67067516],
#        [0.9066419 , 0.74568933, 0.967031  , ..., 0.7393517 , 0.59039956,
#         0.62900144],
#        [0.8159448 , 0.70401824, 0.95718974, ..., 0.81655747, 0.5589296 ,
#         0.75564015],
#        ...,
#        [0.7193017 , 0.7891406 , 0.90497446, ..., 0.71797323, 0.70163333,
#         0.79554945],
#        [0.90716624, 0.8284137 , 0.9262192 , ..., 0.6684682 , 0.80159533,
#         0.74112356],
#        [0.7390649 , 0.7905466 , 0.9538483 , ..., 0.70381886, 0.590093  ,
#         0.6980914 ]], dtype=float32)>
