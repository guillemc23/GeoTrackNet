# %%
import tensorflow as tf
tf.compat.v1.enable_eager_execution()

# %%
x = tf.Variable([1,2,3], dtype=tf.float32)
grad = tf.constant([0.1, 0.2, 0.3])
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=0.001)
optimizer.apply_gradients(zip([grad], [x]))
# Out:
# 2025-07-03 13:17:16.306228: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2025-07-03 13:17:16.313327: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2688010000 Hz
# 2025-07-03 13:17:16.315055: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xb62c1a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-07-03 13:17:16.315099: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
x
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=float32, numpy=array([0.999, 1.999, 2.999], dtype=float32)>

# %%
grad = optimizer.c
