# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {
        'mmsi': pd.Series(dtype='uint32'),
        'logprob': pd.Series(dtype='float32')
    }
)

# %%
df
# Out:
# Empty DataFrame
# Columns: [mmsi, logprob]
# Index: []
