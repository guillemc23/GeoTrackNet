# %%
from migration.config import TrainingConfig, DatasetConfig, OneHotBins

# %%
a = TrainingConfig(
    dataset=DatasetConfig(
        training_pickle='../../data/ct_2017010203_10_20/ct_2017010203_10_20_train.pkl',
        mean_pickle='../../data/ct_2017010203_10_20/mean.pkl'
    ))

# %%
a.model_dump()
# Out:
# {'random_seed': 11,
#  'dataset': {'training_pickle': PosixPath('../../data/ct_2017010203_10_20/ct_2017010203_10_20_train.pkl'),
#   'mean_pickle': PosixPath('../../data/ct_2017010203_10_20/mean.pkl'),
#   'batch_size': 32,
#   'shuffle': False,
#   'encoding_bins': {'lat': 300,
#    'lon': 300,
#    'sog': 30,
#    'cog': 72,
#    'total': 702}},
#  'model': {'bound': <OptimizedBound.elbo: 'elbo'>, 'latent_size': 64},
#  'learning_rate': 0.0003,
#  'log_dir': PosixPath('chkpt')}
